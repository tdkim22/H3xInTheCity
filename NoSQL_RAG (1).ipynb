# %% [markdown]
# # Note: Run code on a GPU
# ## T4 via Colab works well

# %%
#Install required packages
# !pip install pymongo h3 requests pandas
# !pip install srai
# !pip install srai[osm]
# !pip install h3
# !pip install pytorch_lightning
# !pip install hdbscan
# !pip install torch
# !pip install contextily
# !pip install minisom
# Out:
# Collecting pymongo
#   Downloading pymongo-4.17.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting h3
#   Downloading h3-4.4.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.4.22)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pymongo-4.17.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 35.9 MB/s eta 0:00:00
# Downloading h3-4.4.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 73.8 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 36.8 MB/s eta 0:00:00
# Installing collected packages: h3, dnspython, pymongo
# Successfully installed dnspython-2.8.0 h3-4.4.2 pymongo-4.17.0
# Collecting srai
#   Downloading srai-0.10.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from srai) (2.2.2)
# Requirement already satisfied: geopandas>=0.6 in /usr/local/lib/python3.12/dist-packages (from srai) (1.1.3)
# Requirement already satisfied: shapely>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from srai) (2.1.2)
# Requirement already satisfied: h3>=4.0.0b1 in /usr/local/lib/python3.12/dist-packages (from srai) (4.4.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from srai) (2.0.2)
# Collecting pyfunctional>=1.0.0 (from srai)
#   Downloading pyfunctional-1.5.0-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from srai) (18.1.0)
# Collecting topojson>=1.6 (from srai)
#   Downloading topojson-1.10-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: tqdm>=4.42.0 in /usr/local/lib/python3.12/dist-packages (from srai) (4.67.3)
# Collecting s2>=0.1.9 (from srai)
#   Downloading s2-0.1.9-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: typeguard>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from srai) (4.5.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from srai) (2.32.4)
# Collecting h3ronpy>=0.20.1 (from srai)
#   Downloading h3ronpy-0.22.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.8 kB)
# Collecting osmnx>=1.3.0 (from srai)
#   Downloading osmnx-2.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: polars>=0.19.4 in /usr/local/lib/python3.12/dist-packages (from srai) (1.35.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.6->srai) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.6->srai) (26.1)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.6->srai) (3.7.2)
# Collecting arro3-core>=0.4 (from h3ronpy>=0.20.1->srai)
#   Downloading arro3_core-0.8.0-cp311-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (515 bytes)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from osmnx>=1.3.0->srai) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->srai) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->srai) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->srai) (2026.1)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.19.4->srai) (1.35.2)
# Requirement already satisfied: dill>=0.2.5 in /usr/local/lib/python3.12/dist-packages (from pyfunctional>=1.0.0->srai) (0.3.8)
# Requirement already satisfied: tabulate<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pyfunctional>=1.0.0->srai) (0.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->srai) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->srai) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->srai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->srai) (2026.4.22)
# Collecting s2sphere (from s2>=0.1.9->srai)
#   Downloading s2sphere-0.2.5-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: typing_extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from typeguard>=3.0.0->srai) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->srai) (1.17.0)
# Requirement already satisfied: future>=0.15 in /usr/local/lib/python3.12/dist-packages (from s2sphere->s2>=0.1.9->srai) (1.0.0)
# Downloading srai-0.10.2-py3-none-any.whl (173 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.1/173.1 kB 12.6 MB/s eta 0:00:00
# Downloading h3ronpy-0.22.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 80.8 MB/s eta 0:00:00
# Downloading osmnx-2.1.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 11.8 MB/s eta 0:00:00
# Downloading pyfunctional-1.5.0-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.6 MB/s eta 0:00:00
# Downloading s2-0.1.9-py2.py3-none-any.whl (4.1 kB)
# Downloading topojson-1.10-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.3/83.3 kB 10.0 MB/s eta 0:00:00
# Downloading arro3_core-0.8.0-cp311-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 121.3 MB/s eta 0:00:00
# Downloading s2sphere-0.2.5-py2.py3-none-any.whl (23 kB)
# Installing collected packages: s2sphere, pyfunctional, arro3-core, topojson, s2, h3ronpy, osmnx, srai
# Successfully installed arro3-core-0.8.0 h3ronpy-0.22.0 osmnx-2.1.0 pyfunctional-1.5.0 s2-0.1.9 s2sphere-0.2.5 srai-0.10.2 topojson-1.10
# Requirement already satisfied: srai[osm] in /usr/local/lib/python3.12/dist-packages (0.10.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (2.2.2)
# Requirement already satisfied: geopandas>=0.6 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (1.1.3)
# Requirement already satisfied: shapely>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (2.1.2)
# Requirement already satisfied: h3>=4.0.0b1 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (4.4.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (2.0.2)
# Requirement already satisfied: pyfunctional>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (1.5.0)
# Requirement already satisfied: pyarrow>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (18.1.0)
# Requirement already satisfied: topojson>=1.6 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (1.10)
# Requirement already satisfied: tqdm>=4.42.0 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (4.67.3)
# Requirement already satisfied: s2>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (0.1.9)
# Requirement already satisfied: typeguard>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (4.5.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (2.32.4)
# Requirement already satisfied: h3ronpy>=0.20.1 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (0.22.0)
# Requirement already satisfied: osmnx>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (2.1.0)
# Requirement already satisfied: polars>=0.19.4 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (1.35.2)
# Collecting overpass>=0.7 (from srai[osm])
#   Downloading overpass-0.7-py3-none-any.whl.metadata (773 bytes)
# Requirement already satisfied: pillow>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (11.3.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from srai[osm]) (4.13.5)
# Collecting quackosm>=0.11.0 (from srai[osm])
#   Downloading quackosm-0.17.1-py3-none-any.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.6->srai[osm]) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.6->srai[osm]) (26.1)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.6->srai[osm]) (3.7.2)
# Requirement already satisfied: arro3-core>=0.4 in /usr/local/lib/python3.12/dist-packages (from h3ronpy>=0.20.1->srai[osm]) (0.8.0)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from osmnx>=1.3.0->srai[osm]) (3.6.1)
# Collecting geojson>=1.0.9 (from overpass>=0.7->srai[osm])
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->srai[osm]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->srai[osm]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->srai[osm]) (2026.1)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.19.4->srai[osm]) (1.35.2)
# Requirement already satisfied: dill>=0.2.5 in /usr/local/lib/python3.12/dist-packages (from pyfunctional>=1.0.0->srai[osm]) (0.3.8)
# Requirement already satisfied: tabulate<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pyfunctional>=1.0.0->srai[osm]) (0.9.0)
# Requirement already satisfied: duckdb>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from quackosm>=0.11.0->srai[osm]) (1.3.2)
# Collecting geoarrow-pyarrow>=0.1.2 (from quackosm>=0.11.0->srai[osm])
#   Downloading geoarrow_pyarrow-0.2.0-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: psutil>=5.6.2 in /usr/local/lib/python3.12/dist-packages (from quackosm>=0.11.0->srai[osm]) (5.9.5)
# Requirement already satisfied: pooch>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from quackosm>=0.11.0->srai[osm]) (1.9.0)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from quackosm>=0.11.0->srai[osm]) (13.9.4)
# Requirement already satisfied: geopy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from quackosm>=0.11.0->srai[osm]) (2.4.1)
# Collecting rq_geo_toolkit>=2026.2.1 (from quackosm>=0.11.0->srai[osm])
#   Downloading rq_geo_toolkit-2026.4.0-py3-none-any.whl.metadata (489 bytes)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->srai[osm]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->srai[osm]) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->srai[osm]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->srai[osm]) (2026.4.22)
# Requirement already satisfied: s2sphere in /usr/local/lib/python3.12/dist-packages (from s2>=0.1.9->srai[osm]) (0.2.5)
# Requirement already satisfied: typing_extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from typeguard>=3.0.0->srai[osm]) (4.15.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->srai[osm]) (2.8.3)
# Collecting geoarrow-types>=0.3.0 (from geoarrow-pyarrow>=0.1.2->quackosm>=0.11.0->srai[osm])
#   Downloading geoarrow_types-0.3.0-py3-none-any.whl.metadata (409 bytes)
# Collecting geoarrow-c>=0.3.0 (from geoarrow-pyarrow>=0.1.2->quackosm>=0.11.0->srai[osm])
#   Downloading geoarrow_c-0.3.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy>=2.0.0->quackosm>=0.11.0->srai[osm]) (2.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.6.0->quackosm>=0.11.0->srai[osm]) (4.9.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->srai[osm]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->quackosm>=0.11.0->srai[osm]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->quackosm>=0.11.0->srai[osm]) (2.20.0)
# Requirement already satisfied: future>=0.15 in /usr/local/lib/python3.12/dist-packages (from s2sphere->s2>=0.1.9->srai[osm]) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->quackosm>=0.11.0->srai[osm]) (0.1.2)
# Downloading overpass-0.7-py3-none-any.whl (10 kB)
# Downloading quackosm-0.17.1-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 11.0 MB/s eta 0:00:00
# Downloading geoarrow_pyarrow-0.2.0-py3-none-any.whl (25 kB)
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading rq_geo_toolkit-2026.4.0-py3-none-any.whl (15 kB)
# Downloading geoarrow_c-0.3.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 51.4 MB/s eta 0:00:00
# Downloading geoarrow_types-0.3.0-py3-none-any.whl (19 kB)
# Installing collected packages: geojson, geoarrow-types, geoarrow-c, overpass, geoarrow-pyarrow, rq_geo_toolkit, quackosm
# Successfully installed geoarrow-c-0.3.1 geoarrow-pyarrow-0.2.0 geoarrow-types-0.3.0 geojson-3.2.0 overpass-0.7 quackosm-0.17.1 rq_geo_toolkit-2026.4.0
# Requirement already satisfied: h3 in /usr/local/lib/python3.12/dist-packages (4.4.2)
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (2.10.0+cu128)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.67.3)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.0)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (26.1)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.29.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.1.0->pytorch_lightning) (1.5.3)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics>0.7.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.23.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.13)
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 22.6 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 65.5 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.15.3 pytorch_lightning-2.6.1 torchmetrics-1.9.0
# Requirement already satisfied: hdbscan in /usr/local/lib/python3.12/dist-packages (0.8.42)
# Requirement already satisfied: numpy<3,>=1.20 in /usr/local/lib/python3.12/dist-packages (from hdbscan) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from hdbscan) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.6 in /usr/local/lib/python3.12/dist-packages (from hdbscan) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from hdbscan) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6->hdbscan) (3.6.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Collecting contextily
#   Downloading contextily-1.7.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from contextily) (3.10.0)
# Collecting mercantile (from contextily)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from contextily) (11.3.0)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from contextily) (1.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from contextily) (2.32.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from contextily) (1.5.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from contextily) (2026.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy->contextily) (2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.12/dist-packages (from mercantile->contextily) (8.3.3)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->contextily) (26.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio->contextily) (2026.4.22)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->contextily) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->contextily) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->contextily) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.17.0)
# Downloading contextily-1.7.0-py3-none-any.whl (16 kB)
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: mercantile, contextily
# Successfully installed contextily-1.7.0 mercantile-1.2.1
# Collecting minisom
#   Downloading minisom-2.3.6.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: minisom
#   Building wheel for minisom (setup.py) ... done
#   Created wheel for minisom: filename=MiniSom-2.3.6-py3-none-any.whl size=13083 sha256=6377df7fe51b0b7cdb5833ed0984e6b3f055448716f0c21bbe26032228d185f2
#   Stored in directory: /root/.cache/pip/wheels/84/35/b8/48b06bd8cae7187916c28a29c6daa9e0ff610647a2dfa62b97
# Successfully built minisom
# Installing collected packages: minisom
# Successfully installed minisom-2.3.6

# %%
# --- 1. System & Warning Suppression ---
import os
import warnings
import logging

# Filter specific annoying warnings that clutter client outputs
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore', FutureWarning)
warnings.simplefilter('ignore', UserWarning)
warnings.simplefilter('ignore', DeprecationWarning)
os.environ["PYTHONWARNINGS"] = "ignore" # Suppress at system level

# Silence Pytorch Lightning & Library logs
logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)
logging.getLogger("srai").setLevel(logging.WARNING)

# --- 2. Data Manipulation & Math ---
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely import wkt
import itertools

# --- 3. Geospatial & H3 ---
import h3
from srai.loaders import OSMPbfLoader
from srai.regionalizers import geocode_to_region_gdf, H3Regionalizer
from srai.joiners import IntersectionJoiner
from srai.embedders import Hex2VecEmbedder
from srai.neighbourhoods import H3Neighbourhood
from srai.loaders.osm_loaders.filters import HEX2VEC_FILTER # This filter is used for loading specific OSM data
from srai.plotting import plot_regions

# --- 4. Machine Learning & Torch ---
import torch
from pytorch_lightning.callbacks import TQDMProgressBar
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import hdbscan
from sklearn.metrics import adjusted_rand_score, silhouette_score

# --- 5. Visualization ---
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import matplotlib.colors as mcolors

# --- 6. Configuration ---
# Set Matmul precision for Torch
torch.set_float32_matmul_precision('medium')

# Pandas display options
pd.set_option('display.max_columns', None)
pd.set_option('mode.chained_assignment', None) # Suppress SettingWithCopyWarning

# Matplotlib inline
# %matplotlib inline

print("Libraries loaded. Environment configured for clean output.")
# Out:
# Libraries loaded. Environment configured for clean output.

# %% [markdown]
# #Set up MongoDB

# %%
# 1. Fix the APT repo sync error & Install System Dependencies
# We use -o Acquire::Retries=3 and ignore the failing CRAN repo to let the rest install
# !apt-get update -o Acquire::Languages=none
# !apt-get install -y --fix-missing zstd gnupg wget pciutils lshw

# 2. Install MongoDB 7.0 (Official Repository)
# !wget -qO- https://www.mongodb.org/static/pgp/server-7.0.asc | gpg --dearmor | tee /usr/share/keyrings/mongodb-server-7.0.gpg > /dev/null
# !echo "deb [ arch=amd64,arm64 signed-by=/usr/share/keyrings/mongodb-server-7.0.gpg ] https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0 multiverse" | tee /etc/apt/sources.list.d/mongodb-org-7.0.list
# !apt-get update
# !apt-get install -y mongodb-org

# 3. Start MongoDB Service
# !mkdir -p /data/db
import subprocess
# If mongod is already running from a previous failed attempt, this will just handle it
subprocess.Popen(["mongod", "--fork", "--logpath", "/var/log/mongodb.log", "--dbpath", "/data/db"])

# 4. Install Ollama (using the manual method to ensure it lands in the right spot)
# !curl -fsSL https://ollama.com/install.sh | sh

# 5. Start Ollama in the background with a slight delay
import time
import os

ollama_path = "/usr/local/bin/ollama"

if os.path.exists(ollama_path):
    with open("ollama_server.log", "w") as log_file:
        subprocess.Popen([ollama_path, "serve"], stdout=log_file, stderr=log_file)
    print("🚀 Ollama server starting...")
    time.sleep(12)
    # !ollama pull qwen2.5
else:
    print("❌ Ollama installation failed. check the output of the curl command above.")

# 6. Final verification
print("\n--- Diagnostic Check ---")
# !mongosh --eval "db.adminCommand('ping')"
# !ollama list
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,608 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [89.0 kB]
# Get:7 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.1 MB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,990 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [61.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,862 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,237 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,601 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [86.0 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,225 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,292 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,864 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [39.0 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [112 kB]
# Ign:24 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Ign:25 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Ign:26 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Ign:24 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Ign:25 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Ign:26 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Ign:24 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Ign:25 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Ign:26 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Err:24 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
#   Could not connect to ppa.launchpadcontent.net:443 (185.125.190.80), connection timed out
# Err:25 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
#   Unable to connect to ppa.launchpadcontent.net:443:
# Err:26 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
#   Unable to connect to ppa.launchpadcontent.net:443:
# Fetched 41.6 MB in 37s (1,110 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# W: Failed to fetch https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu/dists/jammy/InRelease  Could not connect to ppa.launchpadcontent.net:443 (185.125.190.80), connection timed out
# W: Failed to fetch https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu/dists/jammy/InRelease  Unable to connect to ppa.launchpadcontent.net:443:
# W: Failed to fetch https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu/dists/jammy/InRelease  Unable to connect to ppa.launchpadcontent.net:443:
# W: Some index files failed to download. They have been ignored, or old ones used instead.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gnupg is already the newest version (2.2.27-3ubuntu2.5).
# gnupg set to manually installed.
# wget is already the newest version (1.21.2-2ubuntu1.1).
# The following additional packages will be installed:
#   libpci3 pci.ids usb.ids
# The following NEW packages will be installed:
#   libpci3 lshw pci.ids pciutils usb.ids zstd
# 0 upgraded, 6 newly installed, 0 to remove and 114 not upgraded.
# Need to get 1,486 kB of archives.
# After this operation, 4,951 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pci.ids all 0.0~2022.01.22-1ubuntu0.1 [251 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 lshw amd64 02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1 [322 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 pciutils amd64 1:3.7.0-6 [63.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 usb.ids all 2022.04.02-1 [219 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 1,486 kB in 2s (732 kB/s)
# Selecting previously unselected package pci.ids.
# (Reading database ... 122354 files and directories currently installed.)
# Preparing to unpack .../0-pci.ids_0.0~2022.01.22-1ubuntu0.1_all.deb ...
# Unpacking pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Selecting previously unselected package libpci3:amd64.
# Preparing to unpack .../1-libpci3_1%3a3.7.0-6_amd64.deb ...
# Unpacking libpci3:amd64 (1:3.7.0-6) ...
# Selecting previously unselected package lshw.
# Preparing to unpack .../2-lshw_02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1_amd64.deb ...
# Unpacking lshw (02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1) ...
# Selecting previously unselected package pciutils.
# Preparing to unpack .../3-pciutils_1%3a3.7.0-6_amd64.deb ...
# Unpacking pciutils (1:3.7.0-6) ...
# Selecting previously unselected package usb.ids.
# Preparing to unpack .../4-usb.ids_2022.04.02-1_all.deb ...
# Unpacking usb.ids (2022.04.02-1) ...
# Selecting previously unselected package zstd.
# Preparing to unpack .../5-zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Setting up lshw (02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1) ...
# Setting up usb.ids (2022.04.02-1) ...
# Setting up libpci3:amd64 (1:3.7.0-6) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Setting up pciutils (1:3.7.0-6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# deb [ arch=amd64,arm64 signed-by=/usr/share/keyrings/mongodb-server-7.0.gpg ] https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0 multiverse
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0 InRelease [3,005 B]
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse arm64 Packages [112 kB]
# Hit:8 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Get:10 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 Packages [114 kB]
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Ign:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Ign:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Ign:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Ign:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Ign:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Ign:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Ign:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Ign:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Ign:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Err:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
#   Could not connect to ppa.launchpadcontent.net:443 (185.125.190.80), connection timed out
# Err:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
#   Unable to connect to ppa.launchpadcontent.net:443:
# Err:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
#   Unable to connect to ppa.launchpadcontent.net:443:
# Fetched 228 kB in 37s (6,118 B/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# W: Failed to fetch https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu/dists/jammy/InRelease  Could not connect to ppa.launchpadcontent.net:443 (185.125.190.80), connection timed out
# W: Failed to fetch https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu/dists/jammy/InRelease  Unable to connect to ppa.launchpadcontent.net:443:
# W: Failed to fetch https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu/dists/jammy/InRelease  Unable to connect to ppa.launchpadcontent.net:443:
# W: Some index files failed to download. They have been ignored, or old ones used instead.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   mongodb-database-tools mongodb-mongosh mongodb-org-database
#   mongodb-org-database-tools-extra mongodb-org-mongos mongodb-org-server
#   mongodb-org-shell mongodb-org-tools
# The following NEW packages will be installed:
#   mongodb-database-tools mongodb-mongosh mongodb-org mongodb-org-database
#   mongodb-org-database-tools-extra mongodb-org-mongos mongodb-org-server
#   mongodb-org-shell mongodb-org-tools
# 0 upgraded, 9 newly installed, 0 to remove and 114 not upgraded.
# Need to get 189 MB of archives.
# After this operation, 633 MB of additional disk space will be used.
# Get:1 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-database-tools amd64 100.16.1 [60.7 MB]
# Get:2 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-mongosh amd64 2.8.3 [64.3 MB]
# Get:3 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org-shell amd64 7.0.32 [2,986 B]
# Get:4 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org-server amd64 7.0.32 [37.4 MB]
# Get:5 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org-mongos amd64 7.0.32 [26.2 MB]
# Get:6 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org-database-tools-extra amd64 7.0.32 [7,786 B]
# Get:7 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org-database amd64 7.0.32 [3,426 B]
# Get:8 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org-tools amd64 7.0.32 [2,770 B]
# Get:9 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org amd64 7.0.32 [2,804 B]
# Fetched 189 MB in 3s (55.2 MB/s)
# Selecting previously unselected package mongodb-database-tools.
# (Reading database ... 122408 files and directories currently installed.)
# Preparing to unpack .../0-mongodb-database-tools_100.16.1_amd64.deb ...
# Unpacking mongodb-database-tools (100.16.1) ...
# Selecting previously unselected package mongodb-mongosh.
# Preparing to unpack .../1-mongodb-mongosh_2.8.3_amd64.deb ...
# Unpacking mongodb-mongosh (2.8.3) ...
# Selecting previously unselected package mongodb-org-shell.
# Preparing to unpack .../2-mongodb-org-shell_7.0.32_amd64.deb ...
# Unpacking mongodb-org-shell (7.0.32) ...
# Selecting previously unselected package mongodb-org-server.
# Preparing to unpack .../3-mongodb-org-server_7.0.32_amd64.deb ...
# Unpacking mongodb-org-server (7.0.32) ...
# Selecting previously unselected package mongodb-org-mongos.
# Preparing to unpack .../4-mongodb-org-mongos_7.0.32_amd64.deb ...
# Unpacking mongodb-org-mongos (7.0.32) ...
# Selecting previously unselected package mongodb-org-database-tools-extra.
# Preparing to unpack .../5-mongodb-org-database-tools-extra_7.0.32_amd64.deb ...
# Unpacking mongodb-org-database-tools-extra (7.0.32) ...
# Selecting previously unselected package mongodb-org-database.
# Preparing to unpack .../6-mongodb-org-database_7.0.32_amd64.deb ...
# Unpacking mongodb-org-database (7.0.32) ...
# Selecting previously unselected package mongodb-org-tools.
# Preparing to unpack .../7-mongodb-org-tools_7.0.32_amd64.deb ...
# Unpacking mongodb-org-tools (7.0.32) ...
# Selecting previously unselected package mongodb-org.
# Preparing to unpack .../8-mongodb-org_7.0.32_amd64.deb ...
# Unpacking mongodb-org (7.0.32) ...
# Setting up mongodb-mongosh (2.8.3) ...
# Setting up mongodb-org-server (7.0.32) ...
# Adding system user `mongodb' (UID 104) ...
# Adding new user `mongodb' (UID 104) with group `nogroup' ...
# Not creating home directory `/home/mongodb'.
# Adding group `mongodb' (GID 107) ...
# Done.
# Adding user `mongodb' to group `mongodb' ...
# Adding user mongodb to group mongodb
# Done.
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
# Setting up mongodb-org-shell (7.0.32) ...
# Setting up mongodb-database-tools (100.16.1) ...
# Setting up mongodb-org-mongos (7.0.32) ...
# Setting up mongodb-org-database-tools-extra (7.0.32) ...
# Setting up mongodb-org-database (7.0.32) ...
# Setting up mongodb-org-tools (7.0.32) ...
# Setting up mongodb-org (7.0.32) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# 🚀 Ollama server starting...
#
#
# --- Diagnostic Check ---
# { ok: 1 }
# NAME              ID              SIZE      MODIFIED
# qwen2.5:latest    845dbda0ea48    4.7 GB    1 second ago

# %%
# Check MongoDB
# !mongosh --eval "db.adminCommand('ping')"

# Check Ollama
# !ollama list
# Out:
# { ok: 1 }
# NAME              ID              SIZE      MODIFIED
# qwen2.5:latest    845dbda0ea48    4.7 GB    23 seconds ago

# %%
# =====================================================
# 2.1 GLOBAL REPRODUCIBILITY SETUP
# =====================================================
# Setting seeds ensures that the Neural Network (Hex2Vec)
# and other stochastic processes produce the exact same
# results every time you run this notebook.

import random
import pytorch_lightning as pl

def set_global_seed(seed=42):
    # 1. Python's built-in random module
    random.seed(seed)

    # 2. NumPy (used for mathematical operations and arrays)
    np.random.seed(seed)

    # 3. PyTorch (used by Hex2Vec for weights initialization)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

    # 4. PyTorch Lightning (manages the training loop)
    # This is the most important one for the SRAI library
    pl.seed_everything(seed, workers=True)

# Apply the seed
set_global_seed(42)
print("Global random seed set to 42 for reproducibility.")
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 42
# Global random seed set to 42 for reproducibility.

# %% [markdown]
# # Set area of interest and H3 resolution

# %%
area_of_interest = "Blacksburg, VA"
H3_resolution = 10

# %% [markdown]
# # Generate feature vectors

# %%
# 1. Define Region
area = geocode_to_region_gdf(area_of_interest)

# 2. Load OSM Features
loaderpbf = OSMPbfLoader()
loadergdf = loaderpbf.load(area, HEX2VEC_FILTER)

# 3. H3 Regionalization
regionalizer = H3Regionalizer(resolution = H3_resolution)
regions_gdf = regionalizer.transform(loadergdf)

# 4. Join Features to H3 Regions
joiner = IntersectionJoiner()
joint_gdf = joiner.transform(regions_gdf, loadergdf)
#joint_gdf.head()
loadergdf.head()
#regions_gdf.head()

#print the type of a random entry in loadergdf
print(type(loadergdf.iloc[5][5]))

# Get the list of feature columns from HEX2VEC_FILTER keys
feature_columns = list(HEX2VEC_FILTER.keys())

# Apply the conversion to 0 or 1 for each feature column
for col in feature_columns:
    # Use .loc for column-wise assignment to avoid SettingWithCopyWarning
    # and ensure the whole column is processed efficiently.
    loadergdf.loc[:, col] = loadergdf[col].notna().astype(int)

loadergdf.head()
#len(loadergdf) : 15408
# Out:
#   0%|                                              | 0.00/53.7M [00:00<?, ?B/s]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Finished operation in 0:00:56
# <class 'NoneType'>
#                                                            geometry aeroway  \
# feature_id
# relation/1589880  MULTIPOLYGON (((-80.5824 37.18598, -80.58208 3...       0
# way/429016822     POLYGON ((-80.42826 37.19321, -80.42685 37.193...       0
# way/426064889     POLYGON ((-80.42242 37.18964, -80.42327 37.189...       0
# way/1335106630    POLYGON ((-80.41856 37.19883, -80.41859 37.198...       0
# way/1335106632    POLYGON ((-80.41862 37.19895, -80.41866 37.198...       0
#
#                  amenity building healthcare historic landuse leisure  \
# feature_id
# relation/1589880       0        0          0        0       0       0
# way/429016822          0        0          0        0       1       0
# way/426064889          0        0          0        0       1       0
# way/1335106630         0        1          0        0       0       0
# way/1335106632         0        1          0        0       0       0
#
#                  military natural office shop sport tourism water waterway
# feature_id
# relation/1589880        0       1      0    0     0       0     0        0
# way/429016822           0       0      0    0     0       0     0        0
# way/426064889           0       0      0    0     0       0     0        0
# way/1335106630          0       0      0    0     0       0     0        0
# way/1335106632          0       0      0    0     0       0     0        0

# %%
# Sum up the features for each hex region

# Get the list of feature columns from HEX2VEC_FILTER keys
feature_columns = list(HEX2VEC_FILTER.keys())
joined_features_df = joint_gdf.reset_index()
merged_df = joined_features_df.merge(
    loadergdf[feature_columns], # Select only the feature columns from loadergdf
    left_on='feature_id',
    right_index=True, # Merge on loadergdf's index ('feature_id')
    how='left'
)
#len(merged_df) : 38785
# 3. Group by region_id and sum the feature columns
features_per_hex = merged_df.groupby('region_id')[feature_columns].sum()

print(f"Shape of features_per_hex: {features_per_hex.shape}")
print("First 5 rows of features_per_hex:")
print(features_per_hex.head())

# Print the row of features_per_hex corresponding to hexagon
# resolution 8: 882a8ac655fffff
# resoluteion 9: 892a8ac655bffff
# resolution 10: 8a2a8ac655a7fff
print("\nFeatures for hexagon 8a2a8ac655a7fff:")
print(features_per_hex.loc['8a2a8ac655a7fff'])
# Out:
# Shape of features_per_hex: (14152, 15)
# First 5 rows of features_per_hex:
#                 aeroway amenity building healthcare historic landuse leisure  \
# region_id
# 8a2a8a890007fff       0       0        0          0        0       0       0
# 8a2a8a89000ffff       0       0        0          0        0       0       0
# 8a2a8a890017fff       0       0        0          0        0       0       0
# 8a2a8a89001ffff       0       0        0          0        0       0       0
# 8a2a8a890027fff       0       0        0          0        0       0       0
#
#                 military natural office shop sport tourism water waterway
# region_id
# 8a2a8a890007fff        0       1      0    0     0       0     0        0
# 8a2a8a89000ffff        0       1      0    0     0       0     0        0
# 8a2a8a890017fff        0       1      0    0     0       0     0        0
# 8a2a8a89001ffff        0       1      0    0     0       0     0        0
# 8a2a8a890027fff        0       1      0    0     0       0     0        0
#
# Features for hexagon 8a2a8ac655a7fff:
# aeroway       0
# amenity       2
# building      5
# healthcare    0
# historic      0
# landuse       1
# leisure       0
# military      0
# natural       0
# office        0
# shop          0
# sport         0
# tourism       0
# water         0
# waterway      0
# Name: 8a2a8ac655a7fff, dtype: object

# %% [markdown]
# # Set up RAG functions

# %%
from pymongo import MongoClient, UpdateOne
import pandas as pd

def setup_nosql_and_ingest(features_per_hex: pd.DataFrame, db_name="hex_rag", collection_name="hex_features"):
    # 1. Connect to MongoDB
    client = MongoClient("mongodb://localhost:27017/")
    db = client[db_name]
    collection = db[collection_name]

    # 2. Prepare data
    # Note: Ensure 'region_id' is actually your index name or a column
    df_to_insert = features_per_hex.reset_index()
    records = df_to_insert.to_dict(orient="records")

    if records:
        # 3. Use Bulk Write for efficiency
        # We assume the H3 index column is named 'region_id' in your dataframe
        operations = [
            UpdateOne({"region_id": r["region_id"]}, {"$set": r}, upsert=True)
            for r in records
        ]
        collection.bulk_write(operations)
        print(f"✅ MongoDB Synced: {len(records)} hexes.")

    # 4. Ensure index for fast retrieval
    collection.create_index("region_id", unique=True)
    return collection

def retrieve_neighborhood_context(collection, target_hex: str, rings: int = 1):
    neighborhood_hexes = list(h3.grid_disk(target_hex, rings))
    results = list(collection.find({"region_id": {"$in": neighborhood_hexes}}, {"_id": 0}))

    context = {"target": None, "neighbors": []}
    for row in results:
        if row["region_id"] == target_hex:
            context["target"] = row
        else:
            context["neighbors"].append(row)
    return context

def build_prompt(target_hex: str, context: dict):
    if not context["target"]: return "No data found."

    prompt = f"Analyze H3 Hexagon {target_hex} in Blacksburg, VA.\n\n### Local Features:\n"
    for k, v in context["target"].items():
        if k != "region_id" and v > 0: prompt += f"- {k}: {v}\n"

    if context["neighbors"]:
        prompt += "\n### Nearby Context (Aggregated):\n"
        agg = {}
        for n in context["neighbors"]:
            for k, v in n.items():
                if k != "region_id" and isinstance(v, (int, float)):
                    agg[k] = agg.get(k, 0) + v
        for k, v in agg.items():
            if v > 0: prompt += f"- Nearby {k}: {v}\n"

    prompt += "\nTask: Based on these OSM features, describe the character of this neighborhood."
    #print("The prompt is :" + prompt + "\n")
    return prompt

def generate_insights(prompt: str):
    response = requests.post("http://localhost:11434/api/generate",
                             json={"model": "qwen2.5", "prompt": prompt, "stream": False})
    return response.json().get("response", "Error generating response.")

def run_rag_pipeline(df, query_hex, rings=1):
    col = setup_nosql_and_ingest(df)
    ctx = retrieve_neighborhood_context(col, query_hex, rings)
    prompt = build_prompt(query_hex, ctx)
    print("\n--- INSIGHTS ---\n", generate_insights(prompt))

# %% [markdown]
# # Load Ollama

# %%
import subprocess
import time
import requests

# 1. Kill any ghost processes if they exist
# !pkill ollama

# 2. Start Ollama server and pipe output to a log file
ollama_path = "/usr/local/bin/ollama"
with open("ollama_server.log", "w") as log_file:
    subprocess.Popen([ollama_path, "serve"], stdout=log_file, stderr=log_file)

# 3. Wait and "Ping" the server until it answers
print("Waiting for Ollama to wake up...")
for i in range(20):  # Try for 20 seconds
    try:
        # Port 11434 is the default Ollama API port
        response = requests.get("http://localhost:11434/")
        if response.status_code == 200:
            print("✅ Ollama is officially UP and running!")
            break
    except requests.exceptions.ConnectionError:
        time.sleep(1)
        if i == 19:
            print("❌ Ollama failed to start. Run '!cat ollama_server.log' to see why.")
# Out:
# Waiting for Ollama to wake up...
# ✅ Ollama is officially UP and running!

# %% [markdown]
# # Call pipeline

# %%
# Select a sample hex from your dataframe
test_hex = features_per_hex.index[0]

# Run the full pipeline
run_rag_pipeline(features_per_hex, query_hex=test_hex, rings=1)
# Out:
# ✅ MongoDB Synced: 14152 hexes.
#
# --- INSIGHTS ---
#  Based on the OpenStreetMap (OSM) features provided, we can infer some characteristics about the neighborhood in Blacksburg, VA:
#
# ### Analysis:
# 1. **Hexagon ID: H3 Hexagon 8a2a8a890007fff**
#    - This identifier is part of the Hierarchical High-Density Global Location System (HHGLS), which divides the Earth into hexagonal cells for geospatial analysis and mapping.
#
# 2. **Local Features: natural: 1**
#    - There is one "natural" feature in this area, likely indicating the presence of a natural element such as a park, forest, or water body nearby. This suggests that the neighborhood has some green space or natural landscape which can contribute to a more tranquil and possibly recreational environment.
#
# 3. **Nearby Context: Nearby natural: 6**
#    - The aggregated feature indicates that there are six "natural" features in the surrounding area. This higher concentration of natural elements around the central hexagon suggests that the neighborhood is surrounded by natural areas, which can contribute to a more scenic and possibly greener living environment.
#
# ### Character Description:
# - **Natural Amenities:** The presence of one or multiple natural features (such as parks, forests, or bodies of water) within the immediate area provides residents with easy access to nature. This can enhance the quality of life by offering recreational spaces for activities like walking, hiking, or simply enjoying a peaceful environment.
#
# - **Green Surroundings:** With six nearby natural areas, it is clear that the neighborhood benefits from a substantial amount of green space in its vicinity. This could contribute to a more environmentally friendly and aesthetically pleasing living environment.
#
# - **Potential Scenic Appeal:** The concentration of natural features might also imply that the neighborhood offers scenic views or pathways for residents to explore, adding to the overall charm and attractiveness of the area.
#
# ### Conclusion:
# The neighborhood characterized by H3 Hexagon 8a2a8a890007fff in Blacksburg, VA appears to be one that values natural elements. It is likely a pleasant, green area with easy access to nature, which can provide residents with opportunities for outdoor recreation and enjoyment of the natural environment. This setting could attract individuals who prefer a more tranquil and eco-friendly lifestyle.

# %% [markdown]
# ## Verify hex features

# %%
features_per_hex.index[0]
features_per_hex.head(1)
# Out:
#                 aeroway amenity building healthcare historic landuse leisure  \
# region_id
# 8a2a8a890007fff       0       0        0          0        0       0       0
#
#                 military natural office shop sport tourism water waterway
# region_id
# 8a2a8a890007fff        0       1      0    0     0       0     0        0

# %% [markdown]
# ## Plot hex to visually validate outputs

# %%
import h3
import folium
from shapely.geometry import Polygon

def plot_h3_hex(h3_address):
    # 1. Get the latitude/longitude of the hexagon center
    lat, lng = h3.cell_to_latlng(h3_address)

    # 2. Get the coordinates for the hexagon boundary
    # h3.cell_to_boundary returns (lat, lng) tuples
    boundary = h3.cell_to_boundary(h3_address)

    # 3. Create a Folium map centered on the hexagon
    # Using 'CartoDB dark_matter' for high contrast, as seen in your local files
    m = folium.Map(location=[lat, lng], zoom_start=15, tiles='CartoDB dark_matter')

    # 4. Add the hexagon to the map
    # Note: Folium expects [lat, lng], which matches cell_to_boundary output
    folium.Polygon(
        locations=boundary,
        color='cyan',
        weight=3,
        fill=True,
        fill_color='cyan',
        fill_opacity=0.4,
        tooltip=f"H3 Address: {h3_address}"
    ).add_to(m)

    return m

# Example Usage:
h3_id = features_per_hex.index[0]
map_view = plot_h3_hex(h3_id)
map_view
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_999f830345c17c9d3e21675a5f3299b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_999f830345c17c9d3e21675a5f3299b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_999f830345c17c9d3e21675a5f3299b8 = L.map(
#                 &quot;map_999f830345c17c9d3e21675a5f3299b8&quot;,
#                 {
#                     center: [37.21304813619334, -80.3716444284215],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_409f1b45d8cb34a36bb191f5343ee3e2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_409f1b45d8cb34a36bb191f5343ee3e2.addTo(map_999f830345c17c9d3e21675a5f3299b8);
#
#
#             var polygon_b30fe90152877fd0a3b833b353592463 = L.polygon(
#                 [[37.21366719423765, -80.37146498391573], [37.213477701612234, -80.37228898341473], [37.21285864430921, -80.37246841650563], [37.21242908371927, -80.37182386828957], [37.21261856982216, -80.37099988457898], [37.21323762303739, -80.37082043329623]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cyan&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cyan&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_999f830345c17c9d3e21675a5f3299b8);
#
#
#             polygon_b30fe90152877fd0a3b833b353592463.bindTooltip(
#                 `&lt;div&gt;
#                      H3 Address: 8a2a8a890007fff
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
test_hex = features_per_hex.index[1321]

run_rag_pipeline(features_per_hex, query_hex=test_hex, rings=1)
# Out:
# ✅ MongoDB Synced: 14152 hexes.
#
# --- INSIGHTS ---
#  To analyze the characteristics of the neighborhood in Blacksburg, VA based on the OpenStreetMap (OSM) data provided, we need to interpret the land use and nearby context information.
#
# ### Interpretation of Land Use:
# - **Landuse: 1** - This likely indicates a specific type or category of land use. In OSM, "landuse" tags can represent various types such as residential areas, commercial zones, industrial areas, agricultural lands, forests, parks, etc. Without the exact tag value, we cannot specify precisely what kind of land use it is. However, given that it's a single land use type (1), it could suggest a more specialized or less diverse area.
#
# ### Nearby Context:
# - **Nearby Landuse: 6** - This suggests that within the vicinity, there are multiple different types of land uses. A landuse value of "6" might represent a combination like residential and commercial areas, parks and industrial zones, or other mixed-use developments.
# - **Nearby Natural: 1** - Indicates the presence of natural features such as forests, parks, rivers, etc., which can greatly influence the neighborhood's character by providing green spaces for recreation and aesthetic value.
#
# ### Character of the Neighborhood:
# Based on these features, we can infer that the neighborhood around H3 Hexagon 8a2a8a896cc7fff in Blacksburg, VA has a somewhat specialized land use with a single primary type (possibly residential or commercial) but is situated near diverse and mixed-use areas. The presence of natural elements suggests that the area may have some green spaces or parks nearby, which can contribute to its livability and quality of life.
#
# ### Possible Neighborhood Characteristics:
# 1. **Specialized Use**: The central area might be characterized by a specific type of development (e.g., predominantly residential with occasional commercial elements), which could influence local amenities such as shops, schools, and services.
# 2. **Mix of Surrounding Land Uses**: The diversity in nearby land uses indicates that the neighborhood is part of a larger mixed-use area, likely providing residents with various facilities within a short distance.
# 3. **Natural Amenities**: The presence of natural features implies that there are green spaces or parks nearby, which could be important for recreational activities and enhancing the overall quality of life.
#
# ### Conclusion:
# The neighborhood appears to have a specialized primary land use type but is surrounded by more diverse development types and benefits from nearby natural elements. This combination can contribute to both a distinct character in its primary zone and a wider range of amenities and lifestyle opportunities.

# %%
h3_id = features_per_hex.index[1321]
map_view = plot_h3_hex(h3_id)
map_view
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c92de6c27e00f19f003d9dcb2be9bfd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c92de6c27e00f19f003d9dcb2be9bfd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c92de6c27e00f19f003d9dcb2be9bfd9 = L.map(
#                 &quot;map_c92de6c27e00f19f003d9dcb2be9bfd9&quot;,
#                 {
#                     center: [37.234085176302926, -80.3932424643009],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0815482535df111ce276b57e853d7cdc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0815482535df111ce276b57e853d7cdc.addTo(map_c92de6c27e00f19f003d9dcb2be9bfd9);
#
#
#             var polygon_90f0702bf576856c3484fa8f9746f6d6 = L.polygon(
#                 [[37.23470445825582, -80.39306322226308], [37.23451475069936, -80.3938874819024], [37.23389546949095, -80.394066712516], [37.23346589991982, -80.3934217017038], [37.23365560094423, -80.39259745785738], [37.23427487807172, -80.39241820903044]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cyan&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cyan&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c92de6c27e00f19f003d9dcb2be9bfd9);
#
#
#             polygon_90f0702bf576856c3484fa8f9746f6d6.bindTooltip(
#                 `&lt;div&gt;
#                      H3 Address: 8a2a8a896cc7fff
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
